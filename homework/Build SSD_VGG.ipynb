# %%
from ssd import build_ssd

## box_utils裡面很多Function，可以看看是怎麼設計的
from layers.box_utils import * 
from torch.autograd import Variable
from layers import functions
from layers import modules
from math import sqrt 
from itertools import product
from torch.autograd import Function

import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import argparse
import pickle
import torch.nn.functional as F

# %%
## 詳細模型結構可以參考ssd.py
ssd_net=build_ssd('train', size=300, num_classes=21)
# Out:
# D:\codes\cvdl-1700\1st-DL-CVMarathon\homework\D29-31\Object Detection 程式導讀\ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)

# %% [markdown]
# ## 默認Config檔案在data/config.py內

# %%
ssd_net.cfg
# Out:
# {'num_classes': 21,
#  'lr_steps': (80000, 100000, 120000),
#  'max_iter': 120000,
#  'feature_maps': [38, 19, 10, 5, 3, 1],
#  'min_dim': 300,
#  'steps': [8, 16, 32, 64, 100, 300],
#  'min_sizes': [30, 60, 111, 162, 213, 264],
#  'max_sizes': [60, 111, 162, 213, 264, 315],
#  'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
#  'variance': [0.1, 0.2],
#  'clip': True,
#  'name': 'VOC'}

# %%
cfg = {
    'num_classes': 21,
    'lr_steps': (80000, 100000, 120000),
    'max_iter': 120000,
    'feature_maps': [38, 19, 10, 5, 3, 1],
    'min_dim': 300,
    'steps': [8, 16, 32, 64, 100, 300],
    'min_sizes': [30, 60, 111, 162, 213, 264],
    'max_sizes': [60, 111, 162, 213, 264, 315],
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
    'variance': [0.1, 0.2],
    'clip': True,
    'name': 'VOC',
}

# %% [markdown]
# ### 'aspect_ratios' : 使用六張Feature Map，每一張上方有預設的anchor boxes，Boxes aspect ratio可以自己設定
# ### 'feature_maps' : 使用feature map大小為[38x38, 19x19, 10x10, 5x5, 3x3, 1x1]
# ### 'min_sizes'、'max_sizes'可藉由下方算式算出，由作者自行設計
# ### 'steps' : Feature map回放回原本300*300的比例，如38要回放為300大概就是8倍
# ### 'variance' : Training 的一個trick，加速收斂，詳見：https://github.com/rykov8/ssd_keras/issues/53

# %% [markdown]
# ---

# %% [markdown]
# ## 'min_sizes'、'max_sizes' 計算

# %%
import math
## source:https://blog.csdn.net/gbyy42299/article/details/81235891
min_dim = 300   ## 维度
# conv4_3 ==> 38 x 38
# fc7 ==> 19 x 19
# conv6_2 ==> 10 x 10
# conv7_2 ==> 5 x 5
# conv8_2 ==> 3 x 3
# conv9_2 ==> 1 x 1
mbox_source_layers = ['conv4_3', 'fc7', 'conv6_2', 'conv7_2', 'conv8_2', 'conv9_2'] ## prior_box來源層，可以更改。很多改進都是基於此處的調整。
# in percent %
min_ratio = 20 ## 這裡即是論文中所說的Smin的= 0.2，Smax的= 0.9的初始值，經過下面的運算即可得到min_sizes，max_sizes。
max_ratio = 90
step = int(math.floor((max_ratio - min_ratio) / (len(mbox_source_layers) - 2)))## 取一個間距步長，即在下面用於循環給比取值時起一個間距作用。可以用一個具體的數值代替，這裡等於17。
min_sizes = []  ## 經過以下運算得到min_sizes和max_sizes。
max_sizes = []
for ratio in range(min_ratio, max_ratio + 1, step):
    ## 從min_ratio至max_ratio + 1每隔步驟= 17取一個值賦值給比。注意範圍函數的作用。
    ## min_sizes.append（）函數即把括號內部每次得到的值依次給了min_sizes。
    min_sizes.append(min_dim * ratio / 100.)
    max_sizes.append(min_dim * (ratio + step) / 100.)
min_sizes = [min_dim * 10 / 100.] + min_sizes
max_sizes = [min_dim * 20 / 100.] + max_sizes

## steps: 這一步要仔細理解，即計算卷積層產生的prior_box距離原圖的步長，先驗框中心點的坐標會乘以step，
## 相當於從特徵映射位置映射回原圖位置，比如conv4_3輸出特徵圖大小為38 *38，而輸入的圖片為300* 300，
## 所以38 *8約等於300，所以映射步長為8.這是針對300* 300的訓練圖片。
steps = [8, 16, 32, 64, 100, 300]  
aspect_ratios = [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
 
print('min_sizes: ',min_sizes)
print('max_sizes: ',max_sizes)
# Out:
# min_sizes:  [30.0, 60.0, 111.0, 162.0, 213.0, 264.0]
# max_sizes:  [60.0, 111.0, 162.0, 213.0, 264.0, 315.0]

# %% [markdown]
# ---

# %% [markdown]
# ## Default anchor boxes設計原理，看懂收穫很多
# ##### 可以理解 SSD原文中 8732個anchors是怎麼來的
# ##### 38×38×4+19×19×6+10×10×6+5×5×6+3×3×4+1×1×4=8732

# %%
class PriorBox(object):
    """Compute priorbox coordinates in center-offset form for each source
    feature map.
    """
    def __init__(self, cfg):
        super(PriorBox, self).__init__()
        self.image_size = cfg['min_dim']
        # number of priors for feature map location (either 4 or 6)
        self.num_priors = len(cfg['aspect_ratios'])
        self.variance = cfg['variance'] or [0.1]
        self.feature_maps = cfg['feature_maps']
        self.min_sizes = cfg['min_sizes']
        self.max_sizes = cfg['max_sizes']
        self.steps = cfg['steps']
        self.aspect_ratios = cfg['aspect_ratios']
        self.clip = cfg['clip']
        self.version = cfg['name']
        for v in self.variance:
            if v <= 0:
                raise ValueError('Variances must be greater than 0')

    def forward(self):
        mean = []
        '''依照Feature map大小找出所有的pixel 中心'''
        '''下方這兩個loop會找出W個x軸pixel對上W個y軸pixel，假如現在是在38x38的feature map上，就會有38x38個值'''
        '''ex. [0,1],[0,2]..[0,37] [1,1],[1,2]..[1,37]..........[37,37]'''
        for k, f in enumerate(self.feature_maps):
            for i, j in product(range(f), repeat=2):
                f_k = self.image_size / self.steps[k] ## 如self.steps==8，就是先將原圖size normalize(/300)後再乘上8
                # unit center x,y
                '''中心點'''
                cx = (j + 0.5) / f_k
                cy = (i + 0.5) / f_k

                # aspect_ratio: 1
                # rel size: min_size
                '''/self.image_size 就是在做normalization '''
                s_k = self.min_sizes[k]/self.image_size
                '''小的正方形box'''
                mean += [cx, cy, s_k, s_k]

                # aspect_ratio: 1
                # rel size: sqrt(s_k * s_(k+1))
                '''大的正方形box'''
                s_k_prime = sqrt(s_k * (self.max_sizes[k]/self.image_size))
                mean += [cx, cy, s_k_prime, s_k_prime]

                # rest of aspect ratios
                for ar in self.aspect_ratios[k]:
                    '''aspect ratio 2,3'''
                    mean += [cx, cy, s_k*sqrt(ar), s_k/sqrt(ar)]
                    '''aspect ratio 1/2,1/3'''
                    mean += [cx, cy, s_k/sqrt(ar), s_k*sqrt(ar)]
        # back to torch land
        output = torch.Tensor(mean).view(-1, 4)
        if self.clip:
            output.clamp_(max=1, min=0)
        return output

# %%
PriorBox_Demo=PriorBox(cfg)

# %%
print(PriorBox_Demo.forward().shape)
# Out:
# torch.Size([8732, 4])

# %% [markdown]
# ---

# %% [markdown]
# ## Loss 如何設計

# %%
class MultiBoxLoss(nn.Module):

    def __init__(self, num_classes, overlap_thresh, prior_for_matching,
                 bkg_label, neg_mining, neg_pos, neg_overlap, encode_target,
                 use_gpu=True):
        super(MultiBoxLoss, self).__init__()
        self.use_gpu = use_gpu
        '''有幾類'''
        self.num_classes = num_classes
        '''判定為正樣本的threshold，一般設為0.5'''
        self.threshold = overlap_thresh
        '''background自己會有一類，不用Label，假如我們有20類一樣標註0-19，下方會自己空出一類給background'''
        self.background_label = bkg_label
        self.encode_target = encode_target
        self.use_prior_for_matching = prior_for_matching
        '''OHEM，找出分得最不好的樣品，也就是confidence score比較低的正負樣品'''
        self.do_neg_mining = neg_mining
        '''負樣品與正樣品的比例，通常是3:1'''
        self.negpos_ratio = neg_pos
        self.neg_overlap = neg_overlap
        self.variance = cfg['variance']
     

    def forward(self, predictions, targets):

        '''prediction會output三個值'''
        '''loc shape: bounding box 資訊，torch.size(batch_size,num_priors,4)'''
        '''conf shape: 每一個bounding box 的信心程度，torch.size(batch_size,num_priors,num_classes)'''
        '''priors shape: 預設的defaul box， torch.size(num_priors,4)'''
        loc_data, conf_data, priors = predictions
        num = loc_data.size(0)
        priors = priors[:loc_data.size(1), :]
        num_priors = (priors.size(0))
        num_classes = self.num_classes

        # match priors (default boxes) and ground truth boxes
        loc_t = torch.Tensor(num, num_priors, 4)
        conf_t = torch.LongTensor(num, num_priors)
        if self.use_gpu:
            loc_t = loc_t.cuda()
            conf_t = conf_t.cuda()
        for idx in range(num):
            truths = targets[idx][:, :-1].data
            labels = targets[idx][:, -1].data
            defaults = priors.data
            '''jaccard 計算每一個BBOX與ground truth的IOU'''
            match(self.threshold, truths, defaults, self.variance, labels,
                  loc_t, conf_t, idx)
        '''用Variable包裝'''
        loc_t = Variable(loc_t, requires_grad=False)
        conf_t = Variable(conf_t, requires_grad=False)

        pos = conf_t > 0
        num_pos = pos.sum(dim=1, keepdim=True)


        pos_idx = pos.unsqueeze(pos.dim()).expand_as(loc_data)
        loc_p = loc_data[pos_idx].view(-1, 4)
        loc_t = loc_t[pos_idx].view(-1, 4)
        '''smooth_l1_loss 計算bounding box regression'''
        loss_l = F.smooth_l1_loss(loc_p, loc_t, size_average=False)

        # Compute max conf across batch for hard negative mining
        batch_conf = conf_data.view(-1, self.num_classes)
        loss_c = log_sum_exp(batch_conf) - batch_conf.gather(1, conf_t.view(-1, 1))

        # Hard Negative Mining
        loss_c = loss_c.view(num, -1)
        loss_c[pos] = 0
        '''排列confidence 的分數'''
        _, loss_idx = loss_c.sort(1, descending=True)
        _, idx_rank = loss_idx.sort(1)
        num_pos = pos.long().sum(1, keepdim=True)
        '''負樣品取出數量 == negpos_ratio*num_pos'''
        num_neg = torch.clamp(self.negpos_ratio*num_pos, max=pos.size(1)-1)
        neg = idx_rank < num_neg.expand_as(idx_rank)

        # Confidence Loss Including Positive and Negative Examples
        pos_idx = pos.unsqueeze(2).expand_as(conf_data)
        neg_idx = neg.unsqueeze(2).expand_as(conf_data)
        conf_p = conf_data[(pos_idx+neg_idx).gt(0)].view(-1, self.num_classes)
        targets_weighted = conf_t[(pos+neg).gt(0)]
        '''用cross_entropy做分類'''
        loss_c = F.cross_entropy(conf_p, targets_weighted, size_average=False)

        # Sum of losses: L(x,c,l,g) = (Lconf(x, c) + αLloc(x,l,g)) / N
        #double轉成torch.float64
        N = num_pos.data.sum().double()
        loss_l = loss_l.double()
        loss_c = loss_c.double()
        loss_l /= N
        loss_c /= N
        return loss_l, loss_c

# %% [markdown]
# ## 產生我們Loss function，注意這裡的class要包含背景

# %%
Use_cuda=True
criterion = MultiBoxLoss(21, 0.5, True, 0, False, 3, 0.5,False, Use_cuda,)

# %% [markdown]
# ----

# %% [markdown]
# ## 基本設定

# %%
ssd_net=build_ssd('train', size=300, num_classes=21)
use_pretrained=False
if use_pretrained:
    ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
net=ssd_net

# %%
'''要不要使用gpu'''
Use_cuda=True

'''tensor type會依照cpu或gpu有所不同'''
if torch.cuda.is_available():
    if Use_cuda:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
    else:
        print("WARNING: It looks like you have a CUDA device, but aren't " +
              "using CUDA.\nRun with --cuda for optimal training speed.")
        torch.set_default_tensor_type('torch.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')


'''使用GPU時模型要轉成cuda'''
if Use_cuda:
    net = net.cuda()
    
batch_size_=32
optimizer = optim.Adam(net.parameters(),lr=0.00001/batch_size_)

# %% [markdown]
# ---

# %% [markdown]
# ## 訓練

# %% [markdown]
# ## 這裡我們先示範輸入的 image,Label格式，真正在訓練時，準備成一樣格式即可

# %%
'''輸入影像格式，假設batch size 為 4'''
image_in=torch.tensor(torch.rand(4,3,300,300),dtype=torch.float32)
'''Label格式，沒有固定長度，看圖像中有幾個label就有幾個'''
label_0=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_1=[[ 0.1804,  0.6076,  0.7701,  0.8485, 13.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 11.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 7.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 5.0000],]
label_2=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 14.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_3=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
# Out:
# C:\Users\Bill\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
epochs=300
iteration=1000

# %%
for epoch in range(epochs):
    n=0
    loss_sum=[]
    loc_loss=[]
    conf_loss=[]
    for number__ in range(iteration) :
        '''要用Variable包裝tensor才能送入模型'''
        if Use_cuda:
            image_ = Variable(image_in.cuda())
            y = [Variable(torch.tensor(label_0).cuda(), volatile=True),Variable(torch.tensor(label_1).cuda(), 
                volatile=True),Variable(torch.tensor(label_2).cuda(), volatile=True),Variable(torch.tensor(label_3).cuda(), volatile=True)]      
        else:
            image_ = Variable(image_in)
            y = [Variable(torch.tensor(label_0), volatile=True),Variable(torch.tensor(label_1), 
                volatile=True),Variable(torch.tensor(label_2), volatile=True),Variable(torch.tensor(label_3), volatile=True)]

        '''Forward Pass'''
        out = net(image_)
        '''Regression Loss and Classification Loss'''
        loss_l,loss_c = criterion(out,y)
        loss = loss_l+ loss_c
        '''Backward'''
        loss.backward()

        loc_loss.append(loss_l.data.cpu().numpy())
        conf_loss.append(loss_c.data.cpu().numpy())
        loss_sum.append(loss.data.cpu().numpy())
        '''更新參數'''
        optimizer.step()
        '''清空Gradients'''
        optimizer.zero_grad()
        
        n+=1
        if n%10==0:
            print('BBOX Regression Loss: ', np.mean(loc_loss))
            print('Classification Loss: ', np.mean(conf_loss))
    '''儲存權重'''
    torch.save(ssd_net.state_dict(),'weights/Weights.pth')
# Out:
# C:\Users\Bill\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Bill\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Bill\Anaconda3\lib\site-packages\torch\nn\_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# BBOX Regression Loss:  2.513994824444806
# Classification Loss:  15.241276945891205
# BBOX Regression Loss:  2.513850727787724
# Classification Loss:  15.116497520164208
# BBOX Regression Loss:  2.5137066122926317
# Classification Loss:  15.000860482675058
# BBOX Regression Loss:  2.513562633373119
# Classification Loss:  14.89819434837059
# BBOX Regression Loss:  2.513418714735243
# Classification Loss:  14.801923873336227
# BBOX Regression Loss:  2.513274807400174
# Classification Loss:  14.709019997679157
# BBOX Regression Loss:  2.513130858083251
# Classification Loss:  14.618415081690227
# BBOX Regression Loss:  2.512986889591924
# Classification Loss:  14.529180936460142
# BBOX Regression Loss:  2.5128428832003116
# Classification Loss:  14.440804764861431
# BBOX Regression Loss:  2.512698887012623
# Classification Loss:  14.353008795844184
# BBOX Regression Loss:  2.512554939347084
# Classification Loss:  14.266950757575756
# BBOX Regression Loss:  2.5124109856876324
# Classification Loss:  14.183750322129992
# BBOX Regression Loss:  2.5122669404728124
# Classification Loss:  14.104057707609952
# BBOX Regression Loss:  2.512122780936105
# Classification Loss:  14.027640553630848
# BBOX Regression Loss:  2.511978501684872
# Classification Loss:  13.95405739866657
# BBOX Regression Loss:  2.5118340951425058
# Classification Loss:  13.883319678129974
# BBOX Regression Loss:  2.5116895638260184
# Classification Loss:  13.815313674162157
# BBOX Regression Loss:  2.511544963067451
# Classification Loss:  13.749655302071275
# BBOX Regression Loss:  2.5114002904464394
# Classification Loss:  13.685969225193787
# BBOX Regression Loss:  2.511255532723886
# Classification Loss:  13.623948143853081
# BBOX Regression Loss:  2.5111106495798374
# Classification Loss:  13.563347349890115
# BBOX Regression Loss:  2.5109657647232413
# Classification Loss:  13.50505792380182
# BBOX Regression Loss:  2.51082146808913
# Classification Loss:  13.451061633320439
# BBOX Regression Loss:  2.5106780134601356
# Classification Loss:  13.401168973946278
# BBOX Regression Loss:  2.510535455774378
# Classification Loss:  13.354986472800928
# BBOX Regression Loss:  2.510393778483073
# Classification Loss:  13.31215582953559
# BBOX Regression Loss:  2.5102528732990534
# Classification Loss:  13.272347084746603
# BBOX Regression Loss:  2.5101126252028045
# Classification Loss:  13.23525741012008
# BBOX Regression Loss:  2.5099729194494955
# Classification Loss:  13.200619265189724
# BBOX Regression Loss:  2.509833702746733
# Classification Loss:  13.168201049051168
# BBOX Regression Loss:  2.5096949833695605
# Classification Loss:  13.137794040693604
# BBOX Regression Loss:  2.509556767675612
# Classification Loss:  13.10921559157195
# BBOX Regression Loss:  2.5094190621081696
# Classification Loss:  13.08230565817134
# BBOX Regression Loss:  2.5092818432643784
# Classification Loss:  13.056921253744552
# BBOX Regression Loss:  2.509145054892888
# Classification Loss:  13.032933620876735
# BBOX Regression Loss:  2.5090086619059244
# Classification Loss:  13.010227705716105
# BBOX Regression Loss:  2.5088726314815792
# Classification Loss:  12.988700871281438
# BBOX Regression Loss:  2.508736932765671
# Classification Loss:  12.968260838320846
# BBOX Regression Loss:  2.508601516332382
# Classification Loss:  12.948824412462718
# BBOX Regression Loss:  2.5084663341663505
# Classification Loss:  12.930316518147785
# BBOX Regression Loss:  2.508331312612036
# Classification Loss:  12.912669908752717
# BBOX Regression Loss:  2.5081964099217977
# Classification Loss:  12.895827052202176
# BBOX Regression Loss:  2.5080616158313735
# Classification Loss:  12.879734009735344
# BBOX Regression Loss:  2.5079268914681894
# Classification Loss:  12.86434009436405
# BBOX Regression Loss:  2.5077921511803147
# Classification Loss:  12.849601201814878
# BBOX Regression Loss:  2.507657342563697
# Classification Loss:  12.835477623194697
# BBOX Regression Loss:  2.507522436913024
# Classification Loss:  12.82193054247316
# BBOX Regression Loss:  2.5073874349947327
# Classification Loss:  12.808924105137955
# BBOX Regression Loss:  2.50725233059261
# Classification Loss:  12.796425321294967
# BBOX Regression Loss:  2.5071171179877387
# Classification Loss:  12.78440389223452
# BBOX Regression Loss:  2.506981793017862
# Classification Loss:  12.772831893400083
# BBOX Regression Loss:  2.50684631706303
# Classification Loss:  12.761684063425092
# BBOX Regression Loss:  2.5067106709456963
# Classification Loss:  12.75093783012726
# BBOX Regression Loss:  2.5065748238269197
# Classification Loss:  12.740571209105608
# BBOX Regression Loss:  2.506438763037274
# Classification Loss:  12.730563621649438
# BBOX Regression Loss:  2.506302462683784
# Classification Loss:  12.720895841891174
# BBOX Regression Loss:  2.506165901664947
# Classification Loss:  12.711549985215136
# BBOX Regression Loss:  2.5060290656936277
# Classification Loss:  12.702509540738122
# BBOX Regression Loss:  2.5058918882898014
# Classification Loss:  12.693759015425151
# BBOX Regression Loss:  2.505754338017216
# Classification Loss:  12.685283992437668
# BBOX Regression Loss:  2.5056164174638664
# Classification Loss:  12.677070953980605
# BBOX Regression Loss:  2.505478110364688
# Classification Loss:  12.669107241613464
# BBOX Regression Loss:  2.5053394104578017
# Classification Loss:  12.661380984459395
# BBOX Regression Loss:  2.5052003056914716
# Classification Loss:  12.653881037676777
# BBOX Regression Loss:  2.5050607843208854
# Classification Loss:  12.64659697703826
# BBOX Regression Loss:  2.5049208267503045
# Classification Loss:  12.639518948436185
# BBOX Regression Loss:  2.504780406962448
# Classification Loss:  12.63263774005137
# BBOX Regression Loss:  2.5046395025481845
# Classification Loss:  12.625944680274182
# BBOX Regression Loss:  2.5044980874831997
# Classification Loss:  12.619431567435232
# BBOX Regression Loss:  2.5043561380376262
# Classification Loss:  12.613090652385088
# BBOX Regression Loss:  2.5042136429621022
# Classification Loss:  12.606914608218611
# BBOX Regression Loss:  2.5040705841755178
# Classification Loss:  12.600896532349134
# BBOX Regression Loss:  2.503926944200428
# Classification Loss:  12.595029956153782
# BBOX Regression Loss:  2.5037827057404085
# Classification Loss:  12.58930873622646
# BBOX Regression Loss:  2.5036378411187066
# Classification Loss:  12.58372705078125
# BBOX Regression Loss:  2.5034923326667053
# Classification Loss:  12.578279332389608
# BBOX Regression Loss:  2.503346147119798
# Classification Loss:  12.572960386510191
# BBOX Regression Loss:  2.5031992666854928
# Classification Loss:  12.567765354544122
# BBOX Regression Loss:  2.5030516759029195
# Classification Loss:  12.562689509438732
# BBOX Regression Loss:  2.5029033604374638
# Classification Loss:  12.557728322347007
# BBOX Regression Loss:  2.502754297941092
# Classification Loss:  12.5528774880687
# BBOX Regression Loss:  2.5026044709464936
# Classification Loss:  12.548132996873587
# BBOX Regression Loss:  2.5024538628281574
# Classification Loss:  12.543492118975033
# BBOX Regression Loss:  2.5023024564066896
# Classification Loss:  12.538951507783652
# BBOX Regression Loss:  2.5021502270002514
# Classification Loss:  12.53450756596584
# BBOX Regression Loss:  2.501997148446437
# Classification Loss:  12.530156859562995
# BBOX Regression Loss:  2.501843191238605
# Classification Loss:  12.525896098208765
# BBOX Regression Loss:  2.5016883288168343
# Classification Loss:  12.521722143667715
# BBOX Regression Loss:  2.5015325148602696
# Classification Loss:  12.517632012718476
# BBOX Regression Loss:  2.501375733363776
# Classification Loss:  12.513622829609938
# BBOX Regression Loss:  2.5012179702678052
# Classification Loss:  12.509691851207965
# BBOX Regression Loss:  2.5010591943098923
# Classification Loss:  12.505836469616481
# BBOX Regression Loss:  2.5008993752683506
# Classification Loss:  12.502054181814858
# BBOX Regression Loss:  2.500738487814805
# Classification Loss:  12.498342610532793
# BBOX Regression Loss:  2.5005765067950096
# Classification Loss:  12.494699436953658
# BBOX Regression Loss:  2.500413400155527
# Classification Loss:  12.491122448297196
# BBOX Regression Loss:  2.5002491368734003
# Classification Loss:  12.48760953468419
# BBOX Regression Loss:  2.5000836863269074
# Classification Loss:  12.484158674659643
# BBOX Regression Loss:  2.499917022842082
# Classification Loss:  12.4807679318686
# BBOX Regression Loss:  2.4997491223370587
# Classification Loss:  12.477435415762445
# BBOX Regression Loss:  2.4826626530400024
# Classification Loss:  12.14655049641927
# BBOX Regression Loss:  2.482426141809534
# Classification Loss:  12.146061932599103
# BBOX Regression Loss:  2.4821868331344037
# Classification Loss:  12.14556997793692
# BBOX Regression Loss:  2.481944684629087
# Classification Loss:  12.145073982521339
# BBOX Regression Loss:  2.481699518274378
# Classification Loss:  12.144572866934318
# BBOX Regression Loss:  2.4814510062888813
# Classification Loss:  12.144066855348184
# BBOX Regression Loss:  2.4811989839745574
# Classification Loss:  12.143555656312
# BBOX Regression Loss:  2.480943347789623
# Classification Loss:  12.143039477313007
# BBOX Regression Loss:  2.480683927182798
# Classification Loss:  12.142518195007074
# BBOX Regression Loss:  2.48042083175094
# Classification Loss:  12.14199180320457
# BBOX Regression Loss:  2.4801542108709156
# Classification Loss:  12.141460113011625
# BBOX Regression Loss:  2.479883815624096
# Classification Loss:  12.14092290430893
# BBOX Regression Loss:  2.479609249799679
# Classification Loss:  12.140379955150463
# BBOX Regression Loss:  2.47933022231652
# Classification Loss:  12.139830808286312
# BBOX Regression Loss:  2.479046662883994
# Classification Loss:  12.13927545994888
# BBOX Regression Loss:  2.478758517018071
# Classification Loss:  12.13871394969799
# BBOX Regression Loss:  2.4784655519040837
# Classification Loss:  12.138145981998484
# BBOX Regression Loss:  2.4781674059330188
# Classification Loss:  12.137570931391462
# BBOX Regression Loss:  2.477863726699561
# Classification Loss:  12.136988232707422
# BBOX Regression Loss:  2.4775541969581885
# Classification Loss:  12.136397399902343
# BBOX Regression Loss:  2.4772384347528793
# Classification Loss:  12.135798459330562
# BBOX Regression Loss:  2.476916071060129
# Classification Loss:  12.135191000993002
# BBOX Regression Loss:  2.4765867310061735
# Classification Loss:  12.134574750080201
# BBOX Regression Loss:  2.47625004215005
# Classification Loss:  12.133949665964385
# BBOX Regression Loss:  2.475905436197917
# Classification Loss:  12.13331677698206
# BBOX Regression Loss:  2.4755524225044794
# Classification Loss:  12.132676001220007
# BBOX Regression Loss:  2.475190470084568
# Classification Loss:  12.132026599104348
# BBOX Regression Loss:  2.474819198487297
# Classification Loss:  12.131367710658482
# BBOX Regression Loss:  2.474438093631204
# Classification Loss:  12.130698598420787
# BBOX Regression Loss:  2.474046629917474
# Classification Loss:  12.130018468786169
# BBOX Regression Loss:  2.473644096164863
# Classification Loss:  12.129326575859189
# BBOX Regression Loss:  2.4732297535295844
# Classification Loss:  12.128622242256448
# BBOX Regression Loss:  2.4728030666090155
# Classification Loss:  12.127904930928207
# BBOX Regression Loss:  2.472363424197261
# Classification Loss:  12.127173612839776
# BBOX Regression Loss:  2.47191005807705
# Classification Loss:  12.126427324890459
# BBOX Regression Loss:  2.4714422477125635
# Classification Loss:  12.125665135638704
# BBOX Regression Loss:  2.4709593237341343
# Classification Loss:  12.124885945515828
# BBOX Regression Loss:  2.470460392020599
# Classification Loss:  12.124088616027237
# BBOX Regression Loss:  2.4699445400256153
# Classification Loss:  12.1232717805665
# BBOX Regression Loss:  2.469410764199716
# Classification Loss:  12.122433751424152
# BBOX Regression Loss:  2.468858013480444
# Classification Loss:  12.121573383224472
# BBOX Regression Loss:  2.468284989076106
# Classification Loss:  12.12068925753262
# BBOX Regression Loss:  2.4676899925580216
# Classification Loss:  12.11977967517731
# BBOX Regression Loss:  2.4670714837533456
# Classification Loss:  12.118842844850686
# BBOX Regression Loss:  2.466427864734037
# Classification Loss:  12.117876956139083
# BBOX Regression Loss:  2.465757594822685
# Classification Loss:  12.116880009600505
# BBOX Regression Loss:  2.4650590877067016
# Classification Loss:  12.115850089383558
# BBOX Regression Loss:  2.4643301840181704
# Classification Loss:  12.114785300360785
# BBOX Regression Loss:  2.463568688448144
# Classification Loss:  12.11368306247195
# BBOX Regression Loss:  2.462772017302336
# Classification Loss:  12.112540827998407
# BBOX Regression Loss:  2.4619375573783655
# Classification Loss:  12.111356060662475
# BBOX Regression Loss:  2.461063064401306
# Classification Loss:  12.11012617366606
# BBOX Regression Loss:  2.4601460742750505
# Classification Loss:  12.108848267881127
# BBOX Regression Loss:  2.45918415263193
# Classification Loss:  12.107519305193867
# BBOX Regression Loss:  2.4581747919461545
# Classification Loss:  12.106135882753314
# BBOX Regression Loss:  2.4571152046243983
# Classification Loss:  12.104694239298503
# BBOX Regression Loss:  2.4560026375793496
# Classification Loss:  12.103190651460464
# BBOX Regression Loss:  2.454834498360391
# Classification Loss:  12.101621313570103
# BBOX Regression Loss:  2.45360787745474
# Classification Loss:  12.099981986391267
# BBOX Regression Loss:  2.4523193279313453
# Classification Loss:  12.09826789950147
# BBOX Regression Loss:  2.450965520954885
# Classification Loss:  12.096473679950762
# BBOX Regression Loss:  2.4495430667198117
# Classification Loss:  12.094593843849756
# BBOX Regression Loss:  2.448048121672669
# Classification Loss:  12.092622972025302
# BBOX Regression Loss:  2.446476841855932
# Classification Loss:  12.090555447119254
# BBOX Regression Loss:  2.444825509878305
# Classification Loss:  12.088386089618389
# BBOX Regression Loss:  2.4430904808001617
# Classification Loss:  12.086109391714453
# BBOX Regression Loss:  2.4412680733988075
# Classification Loss:  12.083719081256588
# BBOX Regression Loss:  2.439354359246547
# Classification Loss:  12.081208909311066
# BBOX Regression Loss:  2.4373453821089086
# Classification Loss:  12.078572329051763
# BBOX Regression Loss:  2.435237276390116
# Classification Loss:  12.075802245770813
# BBOX Regression Loss:  2.4330267062955806
# Classification Loss:  12.072891257638787
# BBOX Regression Loss:  2.430710120456209
# Classification Loss:  12.069831474523976
# BBOX Regression Loss:  2.4282840405545945
# Classification Loss:  12.066615020581636
# BBOX Regression Loss:  2.425745991161755
# Classification Loss:  12.06323387596581
# BBOX Regression Loss:  2.4230939692744506
# Classification Loss:  12.05967962269724
# BBOX Regression Loss:  2.420326312290065
# Classification Loss:  12.055943310237533
# BBOX Regression Loss:  2.417442015720824
# Classification Loss:  12.052015422547647
# BBOX Regression Loss:  2.414441970542625
# Classification Loss:  12.047887173586535
# BBOX Regression Loss:  2.4113285805102644
# Classification Loss:  12.043550242206273
# BBOX Regression Loss:  2.408105907616792
# Classification Loss:  12.038996628655328
# BBOX Regression Loss:  2.4047792702436337
# Classification Loss:  12.0342184686857
# BBOX Regression Loss:  2.4013547345982444
# Classification Loss:  12.029208822000532
# BBOX Regression Loss:  2.397839241419345
# Classification Loss:  12.023961168567498
# BBOX Regression Loss:  2.394240517086453
# Classification Loss:  12.018470135777926
# BBOX Regression Loss:  2.3905667406801046
# Classification Loss:  12.012731388399544
# BBOX Regression Loss:  2.3868268322677677
# Classification Loss:  12.006741390836126
# BBOX Regression Loss:  2.383030344872538
# Classification Loss:  12.000497861353068
# BBOX Regression Loss:  2.379187632891466
# Classification Loss:  11.994000064323245
# BBOX Regression Loss:  2.3753090717571257
# Classification Loss:  11.987247904231038
# BBOX Regression Loss:  2.371405190989804
# Classification Loss:  11.980242421342512
# BBOX Regression Loss:  2.367486164091465
# Classification Loss:  11.97298576904595
# BBOX Regression Loss:  2.3635613642644957
# Classification Loss:  11.965481379412225
# BBOX Regression Loss:  2.3596394912981027
# Classification Loss:  11.957734101058856
# BBOX Regression Loss:  2.355728719664709
# Classification Loss:  11.94975012259938
# BBOX Regression Loss:  2.3518369874712555
# Classification Loss:  11.941536464282178
# BBOX Regression Loss:  2.347971378285208
# Classification Loss:  11.933101665826491
# BBOX Regression Loss:  2.3441374039913963
# Classification Loss:  11.924459139724505
# BBOX Regression Loss:  2.340337912602039
# Classification Loss:  11.915633043446327
# BBOX Regression Loss:  2.336574502210692
# Classification Loss:  11.906638161216474
# BBOX Regression Loss:  2.3328478507995607
# Classification Loss:  11.897487244782626
# BBOX Regression Loss:  1.9601941991735388
# Classification Loss:  10.958592054578993
# BBOX Regression Loss:  1.9583620919121636
# Classification Loss:  10.9424318101671
# BBOX Regression Loss:  1.9565210648524909
# Classification Loss:  10.926446759259258
# BBOX Regression Loss:  1.954656378428141
# Classification Loss:  10.910626022904006
# BBOX Regression Loss:  1.9527566839147494
# Classification Loss:  10.8949478036386
# BBOX Regression Loss:  1.9508159943568855
# Classification Loss:  10.879395887586806
# BBOX Regression Loss:  1.9488380331210984
# Classification Loss:  10.863949455786
# BBOX Regression Loss:  1.9468011396902578
# Classification Loss:  10.84862841853389
# BBOX Regression Loss:  1.9446808128199953
# Classification Loss:  10.833439479247042
# BBOX Regression Loss:  1.9424807640358255
# Classification Loss:  10.818355204264323
# BBOX Regression Loss:  1.9402080407447688
# Classification Loss:  10.803355114869397
# BBOX Regression Loss:  1.9378565847137827
# Classification Loss:  10.788447307068624
# BBOX Regression Loss:  1.935435636906203
# Classification Loss:  10.773613232560987
# BBOX Regression Loss:  1.9329584747395188
# Classification Loss:  10.758826830021286
# BBOX Regression Loss:  1.930441665649414
# Classification Loss:  10.744059335214121
# BBOX Regression Loss:  1.927890765225446
# Classification Loss:  10.72929020634404
# BBOX Regression Loss:  1.9253088068079063
# Classification Loss:  10.714501208469498
# BBOX Regression Loss:  1.922703370145319
# Classification Loss:  10.69967817141686
# BBOX Regression Loss:  1.920075572350337
# Classification Loss:  10.684811472753335
# BBOX Regression Loss:  1.9174286086470993
# Classification Loss:  10.669885785138165
# BBOX Regression Loss:  1.9147681846820488
# Classification Loss:  10.654885385234099
# BBOX Regression Loss:  1.9120936801537922
# Classification Loss:  10.639801451814694
# BBOX Regression Loss:  1.9094052515935973
# Classification Loss:  10.624623842592591
# BBOX Regression Loss:  1.9067036834763893
# Classification Loss:  10.609340083746263
# BBOX Regression Loss:  1.903985709861473
# Classification Loss:  10.593941550925924
# BBOX Regression Loss:  1.9012516695549686
# Classification Loss:  10.57841340415498
# BBOX Regression Loss:  1.8985040180640618
# Classification Loss:  10.562746196061333
# BBOX Regression Loss:  1.8957441723535933
# Classification Loss:  10.546927360252097
# BBOX Regression Loss:  1.8929725593381763
# Classification Loss:  10.530943132695263
# BBOX Regression Loss:  1.890189126568076
# Classification Loss:  10.514782469949603
# BBOX Regression Loss:  1.8873933028719048
# Classification Loss:  10.49843435709052
# BBOX Regression Loss:  1.8845855492132682
# Classification Loss:  10.481879403856066
# BBOX Regression Loss:  1.8817648916533498
# Classification Loss:  10.465097789143607
# BBOX Regression Loss:  1.8789327933118236
# Classification Loss:  10.44806792813968
# BBOX Regression Loss:  1.8760896926960617
# Classification Loss:  10.43077497855696
# BBOX Regression Loss:  1.8732352566817172
# Classification Loss:  10.413206566704645
# BBOX Regression Loss:  1.8703701595882993
# Classification Loss:  10.395339886395185
# BBOX Regression Loss:  1.867493502298991
# Classification Loss:  10.377163975884809
# BBOX Regression Loss:  1.8646050868890225
# Classification Loss:  10.358665566294961
# BBOX Regression Loss:  1.8617056454552545
# Classification Loss:  10.339831461023401
# BBOX Regression Loss:  1.8587967546113247
# Classification Loss:  10.320637508071856
# BBOX Regression Loss:  1.8558788161639395
# Classification Loss:  10.301057255120925
# BBOX Regression Loss:  1.85295366325017
# Classification Loss:  10.28106382831636
# BBOX Regression Loss:  1.8500228242842034
# Classification Loss:  10.260630735403762
# BBOX Regression Loss:  1.8470866717428827
# Classification Loss:  10.239732368375048
# BBOX Regression Loss:  1.844148401208162
# Classification Loss:  10.218333037003227
# BBOX Regression Loss:  1.8412089534966942
# Classification Loss:  10.196398302924454
# BBOX Regression Loss:  1.838268529044257
# Classification Loss:  10.173902407987617
# BBOX Regression Loss:  1.8353265792604476
# Classification Loss:  10.150820806363452
# BBOX Regression Loss:  1.832377543979221
# Classification Loss:  10.127136354799624
# BBOX Regression Loss:  1.8294254519061586
# Classification Loss:  10.102810268914604
# BBOX Regression Loss:  1.826476976606581
# Classification Loss:  10.07779809022561
# BBOX Regression Loss:  1.8235347646503994
# Classification Loss:  10.052061641541167
# BBOX Regression Loss:  1.8206003196936085
# Classification Loss:  10.025562173348886
# BBOX Regression Loss:  1.8176707512441306
# Classification Loss:  9.998257568564881
# BBOX Regression Loss:  1.8147383220612057
# Classification Loss:  9.970116738415271
# BBOX Regression Loss:  1.8118045192170715
# Classification Loss:  9.941106770238449
# BBOX Regression Loss:  1.8088659274319274
# Classification Loss:  9.911194942859245
# BBOX Regression Loss:  1.8059116818511252
# Classification Loss:  9.880354718090375
# BBOX Regression Loss:  1.8029324442074623
# Classification Loss:  9.848569430127556
# BBOX Regression Loss:  1.799911799659567
# Classification Loss:  9.815832200829158
# BBOX Regression Loss:  1.7968349137756274
# Classification Loss:  9.782127604604195
# BBOX Regression Loss:  1.793695276250284
# Classification Loss:  9.747438278960733
# BBOX Regression Loss:  1.7904738558663262
# Classification Loss:  9.71178067525228
# BBOX Regression Loss:  1.7871522700209221
# Classification Loss:  9.675186891039553
# BBOX Regression Loss:  1.7837168709597604
# Classification Loss:  9.637695805713385
# BBOX Regression Loss:  1.7801546878087184
# Classification Loss:  9.599335862260421
# BBOX Regression Loss:  1.7764659330995514
# Classification Loss:  9.560111512493723
# BBOX Regression Loss:  1.7726393150374637
# Classification Loss:  9.520073748684288
# BBOX Regression Loss:  1.7686472905880561
# Classification Loss:  9.479325706037894
# BBOX Regression Loss:  1.7644915256888283
# Classification Loss:  9.437953232997522
# BBOX Regression Loss:  1.760173767191883
# Classification Loss:  9.396034319214369
# BBOX Regression Loss:  1.7556773316854148
# Classification Loss:  9.353676317622371
# BBOX Regression Loss:  1.7509923723008898
# Classification Loss:  9.31095864999521
# BBOX Regression Loss:  1.7461043222686392
# Classification Loss:  9.267969988034094
# BBOX Regression Loss:  1.7410220172205397
# Classification Loss:  9.224778517040825
# BBOX Regression Loss:  1.7357525686508992
# Classification Loss:  9.181442969736427
# BBOX Regression Loss:  1.7302884309266935
# Classification Loss:  9.13803683405022
# BBOX Regression Loss:  1.7246051895635204
# Classification Loss:  9.094641851540525
# BBOX Regression Loss:  1.7186568214275217
# Classification Loss:  9.051368531827572
# BBOX Regression Loss:  1.7124155774528598
# Classification Loss:  9.008306335672483
# BBOX Regression Loss:  1.7059242598301891
# Classification Loss:  8.96547030592783
# BBOX Regression Loss:  1.6992317629520086
# Classification Loss:  8.922871098652422
# BBOX Regression Loss:  1.6923794120707842
# Classification Loss:  8.880527942395085
# BBOX Regression Loss:  1.6853928709341808
# Classification Loss:  8.83844708876932
# BBOX Regression Loss:  1.6782927191123995
# Classification Loss:  8.796631109745311
# BBOX Regression Loss:  1.6710929709020803
# Classification Loss:  8.755078551778391
# BBOX Regression Loss:  1.6637990995689673
# Classification Loss:  8.713795585503883
# BBOX Regression Loss:  1.6564179283551657
# Classification Loss:  8.672791519831778
# BBOX Regression Loss:  1.6489381706959916
# Classification Loss:  8.632101064925331
# BBOX Regression Loss:  1.64136721432864
# Classification Loss:  8.591732208661835
# BBOX Regression Loss:  1.6337155783617938
# Classification Loss:  8.551690188544576
# BBOX Regression Loss:  1.6259918338224169
# Classification Loss:  8.511979585356658
# BBOX Regression Loss:  1.618198092139735
# Classification Loss:  8.47260694270814
# BBOX Regression Loss:  1.6103379418743053
# Classification Loss:  8.433574827316908
# BBOX Regression Loss:  1.6024162868658702
# Classification Loss:  8.394883158766193
# BBOX Regression Loss:  1.594435157134998
# Classification Loss:  8.356532335081097
# BBOX Regression Loss:  1.586393318046518
# Classification Loss:  8.318527007733703
# BBOX Regression Loss:  1.5782913477733882
# Classification Loss:  8.280869166199027
# BBOX Regression Loss:  1.5701380921116583
# Classification Loss:  8.243547151071054
# BBOX Regression Loss:  0.7424104196053964
# Classification Loss:  4.506589847140842
# BBOX Regression Loss:  0.7320377208568432
# Classification Loss:  4.485817139237016
# BBOX Regression Loss:  0.7215778892422899
# Classification Loss:  4.4654551941671485
# BBOX Regression Loss:  0.7111204376927129
# Classification Loss:  4.445291505036531
# BBOX Regression Loss:  0.7006866271407517
# Classification Loss:  4.425332505967882
# BBOX Regression Loss:  0.6903356693409108
# Classification Loss:  4.405639266967774
# BBOX Regression Loss:  0.6800316452349303
# Classification Loss:  4.386244556891223
# BBOX Regression Loss:  0.6697637429943791
# Classification Loss:  4.367106095066777
# BBOX Regression Loss:  0.6595392705972303
# Classification Loss:  4.348181507126293
# BBOX Regression Loss:  0.6493461464069508
# Classification Loss:  4.329414613511828
# BBOX Regression Loss:  0.6392322251290985
# Classification Loss:  4.310753693243471
# BBOX Regression Loss:  0.6292745057447457
# Classification Loss:  4.292160735895605
# BBOX Regression Loss:  0.6195522052949649
# Classification Loss:  4.273592433223017
# BBOX Regression Loss:  0.6101193867032491
# Classification Loss:  4.255044933097071
# BBOX Regression Loss:  0.6009975930202154
# Classification Loss:  4.236520483699846
# BBOX Regression Loss:  0.592143918408288
# Classification Loss:  4.218050751862703
# BBOX Regression Loss:  0.5835087738785089
# Classification Loss:  4.1996660186834065
# BBOX Regression Loss:  0.5750975500899578
# Classification Loss:  4.181371112713598
# BBOX Regression Loss:  0.5668927752251282
# Classification Loss:  4.163187545270715
# BBOX Regression Loss:  0.5588920875831886
# Classification Loss:  4.1451226665355545
# BBOX Regression Loss:  0.5511064655566341
# Classification Loss:  4.127147822573493
# BBOX Regression Loss:  0.5435338180875938
# Classification Loss:  4.109238047230525
# BBOX Regression Loss:  0.5361371792840881
# Classification Loss:  4.091411938260335
# BBOX Regression Loss:  0.5288917938868205
# Classification Loss:  4.0736993836767885
# BBOX Regression Loss:  0.5217718990467213
# Classification Loss:  4.056120989764178
# BBOX Regression Loss:  0.5147542987453972
# Classification Loss:  4.038686527350009
# BBOX Regression Loss:  0.5078431511448571
# Classification Loss:  4.0213978572473925
# BBOX Regression Loss:  0.5010595935993093
# Classification Loss:  4.004241716294062
# BBOX Regression Loss:  0.4944004213520698
# Classification Loss:  3.987216551915896
# BBOX Regression Loss:  0.48784855312771264
# Classification Loss:  3.9703244329381877
# BBOX Regression Loss:  0.4814002367473132
# Classification Loss:  3.9535473621874297
# BBOX Regression Loss:  0.4750525439778964
# Classification Loss:  3.936873380343119
# BBOX Regression Loss:  0.4687989748153087
# Classification Loss:  3.9202961862823105
# BBOX Regression Loss:  0.4626345285403183
# Classification Loss:  3.903807107763353
# BBOX Regression Loss:  0.45655906349262865
# Classification Loss:  3.8873947692548154
# BBOX Regression Loss:  0.4505621885075981
# Classification Loss:  3.8710606406255024
# BBOX Regression Loss:  0.44463902908760505
# Classification Loss:  3.854793926617046
# BBOX Regression Loss:  0.43877744340060054
# Classification Loss:  3.8385942031533156
# BBOX Regression Loss:  0.4329800849852965
# Classification Loss:  3.8224748435749514
# BBOX Regression Loss:  0.42727348892777056
# Classification Loss:  3.806425945140697
# BBOX Regression Loss:  0.42168691543813425
# Classification Loss:  3.790439187371203
# BBOX Regression Loss:  0.41623780256436194
# Classification Loss:  3.7745006648741493
# BBOX Regression Loss:  0.4109297508417174
# Classification Loss:  3.758600577026683
# BBOX Regression Loss:  0.40575148866634175
# Classification Loss:  3.742747511687102
# BBOX Regression Loss:  0.4007043637954649
# Classification Loss:  3.726938717689043
# BBOX Regression Loss:  0.39579153790374116
# Classification Loss:  3.7111639136469496
# BBOX Regression Loss:  0.39100606131497284
# Classification Loss:  3.6954233137991976
# BBOX Regression Loss:  0.38634003036552006
# Classification Loss:  3.679716680079331
# BBOX Regression Loss:  0.38178311043045143
# Classification Loss:  3.6640440504747365
# BBOX Regression Loss:  0.37733622437936293
# Classification Loss:  3.648398542050962
# BBOX Regression Loss:  0.372996666021077
# Classification Loss:  3.6327773122572777
# BBOX Regression Loss:  0.3687618545317582
# Classification Loss:  3.6171778784857853
# BBOX Regression Loss:  0.36462522944231124
# Classification Loss:  3.6016002769656814
# BBOX Regression Loss:  0.36058390021160636
# Classification Loss:  3.586041156679841
# BBOX Regression Loss:  0.3566363547065041
# Classification Loss:  3.57049390439634
# BBOX Regression Loss:  0.35278126573751845
# Classification Loss:  3.554959599933927
# BBOX Regression Loss:  0.34901631395874116
# Classification Loss:  3.5394326515519987
# BBOX Regression Loss:  0.34533176764674567
# Classification Loss:  3.5239182278571004
# BBOX Regression Loss:  0.34172425404780327
# Classification Loss:  3.5084159745709074
# BBOX Regression Loss:  0.3381887103157279
# Classification Loss:  3.4929231865023396
# BBOX Regression Loss:  0.3347231953377136
# Classification Loss:  3.477436950905944
# BBOX Regression Loss:  0.3313303973654835
# Classification Loss:  3.4619503235446656
# BBOX Regression Loss:  0.32800540682990575
# Classification Loss:  3.446462739095626
# BBOX Regression Loss:  0.3247486080422446
# Classification Loss:  3.430965791366718
# BBOX Regression Loss:  0.3215579222138451
# Classification Loss:  3.415453950713503
# BBOX Regression Loss:  0.3184344257569875
# Classification Loss:  3.3999293698740063
# BBOX Regression Loss:  0.31537869378570166
# Classification Loss:  3.384393777842018
# BBOX Regression Loss:  0.3123883705772865
# Classification Loss:  3.3688516714474215
# BBOX Regression Loss:  0.3094598029418716
# Classification Loss:  3.3533056245845807
# BBOX Regression Loss:  0.3065903433794698
# Classification Loss:  3.3377587537412294
# BBOX Regression Loss:  0.30377179011741406
# Classification Loss:  3.3222219289064285
# BBOX Regression Loss:  0.3010026207921927
# Classification Loss:  3.3066996435079066
# BBOX Regression Loss:  0.2982874134964655
# Classification Loss:  3.291189418814014
# BBOX Regression Loss:  0.29562549851200837
# Classification Loss:  3.2756910064437608
# BBOX Regression Loss:  0.29301591831960794
# Classification Loss:  3.260206362877363
# BBOX Regression Loss:  0.29046031177392484
# Classification Loss:  3.2447341811122485
# BBOX Regression Loss:  0.2879559386745561
# Classification Loss:  3.229272886444136
# BBOX Regression Loss:  0.28549890887250473
# Classification Loss:  3.21382464257627
# BBOX Regression Loss:  0.28308625062530274
# Classification Loss:  3.198392269458225
# BBOX Regression Loss:  0.2807186820882338
# Classification Loss:  3.182977323885317
# BBOX Regression Loss:  0.2783912406318745
# Classification Loss:  3.167586444772756
# BBOX Regression Loss:  0.2761032807579316
# Classification Loss:  3.1522213738569826
# BBOX Regression Loss:  0.2738544841261646
# Classification Loss:  3.136884854958027
# BBOX Regression Loss:  0.2716438830003957
# Classification Loss:  3.1215807749901288
# BBOX Regression Loss:  0.2694699213655426
# Classification Loss:  3.106313494680234
# BBOX Regression Loss:  0.26733259585887376
# Classification Loss:  3.0910847694272117
# BBOX Regression Loss:  0.26522983042114895
# Classification Loss:  3.075897544350914
# BBOX Regression Loss:  0.2631597233541084
# Classification Loss:  3.0607571012644654
# BBOX Regression Loss:  0.26111827150663136
# Classification Loss:  3.0456692114999475
# BBOX Regression Loss:  0.2591043590518182
# Classification Loss:  3.0306360783204127
# BBOX Regression Loss:  0.2571193690216536
# Classification Loss:  3.0156557476709756
# BBOX Regression Loss:  0.2551628714790283
# Classification Loss:  3.0007278660453265
# BBOX Regression Loss:  0.2532328513645642
# Classification Loss:  2.9858569709963176
# BBOX Regression Loss:  0.25132886875417876
# Classification Loss:  2.971044759547457
# BBOX Regression Loss:  0.24945098899726045
# Classification Loss:  2.956292842842682
# BBOX Regression Loss:  0.2475990301159061
# Classification Loss:  2.9416026395044215
# BBOX Regression Loss:  0.24576956738766573
# Classification Loss:  2.926978426536744
# BBOX Regression Loss:  0.2439603313837462
# Classification Loss:  2.91242299386253
# BBOX Regression Loss:  0.24217141985313478
# Classification Loss:  2.8979366764877783
# BBOX Regression Loss:  0.24039554667031326
# Classification Loss:  2.883531033692537
# BBOX Regression Loss:  0.06098923109195851
# Classification Loss:  1.4385748404043692
# BBOX Regression Loss:  0.05980248120095995
# Classification Loss:  1.4288646980568216
# BBOX Regression Loss:  0.05897335064263991
# Classification Loss:  1.4188975816891518
# BBOX Regression Loss:  0.05816355789149248
# Classification Loss:  1.4090075174967447
# BBOX Regression Loss:  0.05733641112292255
# Classification Loss:  1.3992105893735534
# BBOX Regression Loss:  0.05645887380764809
# Classification Loss:  1.3895035731939622
# BBOX Regression Loss:  0.05554960612897519
# Classification Loss:  1.3798722221737818
# BBOX Regression Loss:  0.054639524828504635
# Classification Loss:  1.370318967324716
# BBOX Regression Loss:  0.053735857784993374
# Classification Loss:  1.3608450367617508
# BBOX Regression Loss:  0.05283591641320122
# Classification Loss:  1.351459366127297
# BBOX Regression Loss:  0.05191435850027835
# Classification Loss:  1.3414961728182704
# BBOX Regression Loss:  0.05099581741256479
# Classification Loss:  1.3271730746751949
# BBOX Regression Loss:  0.050479236729124674
# Classification Loss:  1.3107042937536864
# BBOX Regression Loss:  0.04929204496441695
# Classification Loss:  1.2948082257830906
# BBOX Regression Loss:  0.04788910468419393
# Classification Loss:  1.2799541713573315
# BBOX Regression Loss:  0.04637910603649086
# Classification Loss:  1.2655568467246163
# BBOX Regression Loss:  0.044834299726423874
# Classification Loss:  1.2534226976448675
# BBOX Regression Loss:  0.043341906068256365
# Classification Loss:  1.2421835605009102
# BBOX Regression Loss:  0.04197589065480185
# Classification Loss:  1.218424483628301
# BBOX Regression Loss:  0.04062913555237982
# Classification Loss:  1.195657624491939
# BBOX Regression Loss:  0.039310727937301414
# Classification Loss:  1.1738049488639495
# BBOX Regression Loss:  0.03803572385800808
# Classification Loss:  1.1523490992459384
# BBOX Regression Loss:  0.03681296175900673
# Classification Loss:  1.1333723783876968
# BBOX Regression Loss:  0.03564935459950824
# Classification Loss:  1.114999712249379
# BBOX Regression Loss:  0.03495644222586243
# Classification Loss:  1.1179218504163952
# BBOX Regression Loss:  0.03499189905843504
# Classification Loss:  1.1087847304819656
# BBOX Regression Loss:  0.03462407749417061
# Classification Loss:  1.0978345499444238
# BBOX Regression Loss:  0.034101846792473994
# Classification Loss:  1.0865892415324214
# BBOX Regression Loss:  0.03358161360938887
# Classification Loss:  1.0749344144896682
# BBOX Regression Loss:  0.03302100224811354
# Classification Loss:  1.0635984618575485
# BBOX Regression Loss:  0.03244091336267112
# Classification Loss:  1.0526852333132655
# BBOX Regression Loss:  0.03186949857993534
# Classification Loss:  1.042044206460317
# BBOX Regression Loss:  0.03130051729621577
# Classification Loss:  1.031843864021344
# BBOX Regression Loss:  0.030737697920703164
# Classification Loss:  1.0220909739891169
# BBOX Regression Loss:  0.03018571335014212
# Classification Loss:  1.012733154095039
# BBOX Regression Loss:  0.02964165401280908
# Classification Loss:  1.0036003275663272
# BBOX Regression Loss:  0.029101311896477376
# Classification Loss:  0.9947940763410505
# BBOX Regression Loss:  0.028563152538289335
# Classification Loss:  0.9861625996714215
# BBOX Regression Loss:  0.028027159691649393
# Classification Loss:  0.9777405029688127
# BBOX Regression Loss:  0.027494547902433962
# Classification Loss:  0.9697420227969136
# BBOX Regression Loss:  0.02697638680429855
# Classification Loss:  0.9618889025556364
# BBOX Regression Loss:  0.02646626369137402
# Classification Loss:  0.9543634650147992
# BBOX Regression Loss:  0.025967413670897582
# Classification Loss:  0.9470544864348971
# BBOX Regression Loss:  0.025478085309818942
# Classification Loss:  0.9398657716885961
# BBOX Regression Loss:  0.02499848747878899
# Classification Loss:  0.9331714989619
# BBOX Regression Loss:  0.02453528744754968
# Classification Loss:  0.9266216585217658
# BBOX Regression Loss:  0.02408909233444032
# Classification Loss:  0.9205432102753479
# BBOX Regression Loss:  0.023663821067936998
# Classification Loss:  0.9147015692275247
# BBOX Regression Loss:  0.023255966785655995
# Classification Loss:  0.908964306318841
# BBOX Regression Loss:  0.022857452386507285
# Classification Loss:  0.903427653418647
# BBOX Regression Loss:  0.022470605926359577
# Classification Loss:  0.8980471419179968
# BBOX Regression Loss:  0.02209546356395609
# Classification Loss:  0.8928675277959927
# BBOX Regression Loss:  0.021732202726777495
# Classification Loss:  0.8878593800702685
# BBOX Regression Loss:  0.021381180193300764
# Classification Loss:  0.8830212429554212
# BBOX Regression Loss:  0.02104093087191132
# Classification Loss:  0.8783504279293998
# BBOX Regression Loss:  0.020711420108835216
# Classification Loss:  0.8738206215005703
# BBOX Regression Loss:  0.02039148903526293
# Classification Loss:  0.8693645313701667
# BBOX Regression Loss:  0.020079367115170638
# Classification Loss:  0.865060154292471
# BBOX Regression Loss:  0.01977642135085434
# Classification Loss:  0.8608860731873211
# BBOX Regression Loss:  0.01948233101746918
# Classification Loss:  0.8567897494045303
# BBOX Regression Loss:  0.019195207139408147
# Classification Loss:  0.8527873294601023
# BBOX Regression Loss:  0.018915381250077395
# Classification Loss:  0.8489187223509648
# BBOX Regression Loss:  0.018643136625821486
# Classification Loss:  0.8451172829234973
# BBOX Regression Loss:  0.01837754383946217
# Classification Loss:  0.8414074333729568
# BBOX Regression Loss:  0.018118419295065424
# Classification Loss:  0.8377984407212999
# BBOX Regression Loss:  0.017866029560055865
# Classification Loss:  0.834284897471384
# BBOX Regression Loss:  0.01762021008596821
# Classification Loss:  0.8308271101260462
# BBOX Regression Loss:  0.01737980116057273
# Classification Loss:  0.8274576350234952
# BBOX Regression Loss:  0.017145440005409865
# Classification Loss:  0.8241817232747264
# BBOX Regression Loss:  0.016916749741704692
# Classification Loss:  0.8209855172495363
# BBOX Regression Loss:  0.016693586509249205
# Classification Loss:  0.817830836356277
# BBOX Regression Loss:  0.01647577674315913
# Classification Loss:  0.8148251989741384
# BBOX Regression Loss:  0.01626486349397281
# Classification Loss:  0.8119257372929202
# BBOX Regression Loss:  0.01606017581678487
# Classification Loss:  0.8090684978572933
# BBOX Regression Loss:  0.015859972339721373
# Classification Loss:  0.8062766053941516
# BBOX Regression Loss:  0.015664787286779974
# Classification Loss:  0.8035690447043258
# BBOX Regression Loss:  0.015475140733195504
# Classification Loss:  0.8009265588647532
# BBOX Regression Loss:  0.015290336626168811
# Classification Loss:  0.7983198209365888
# BBOX Regression Loss:  0.01510931457014317
# Classification Loss:  0.7957737955307099
# BBOX Regression Loss:  0.014932307362194277
# Classification Loss:  0.7932909325317101
# BBOX Regression Loss:  0.014759641096326359
# Classification Loss:  0.7908778706477775
# BBOX Regression Loss:  0.014591231257524324
# Classification Loss:  0.7885029106174597
# BBOX Regression Loss:  0.01442640737723102
# Classification Loss:  0.786179749021994
# BBOX Regression Loss:  0.014265238634529121
# Classification Loss:  0.7839178543662688
# BBOX Regression Loss:  0.014107868826028958
# Classification Loss:  0.7816887976453195
# BBOX Regression Loss:  0.013953774903710804
# Classification Loss:  0.7795045340091992
# BBOX Regression Loss:  0.013802929189596953
# Classification Loss:  0.7773649520191958
# BBOX Regression Loss:  0.013655399241381223
# Classification Loss:  0.775265806251102
# BBOX Regression Loss:  0.013510776481610932
# Classification Loss:  0.7732066974806577
# BBOX Regression Loss:  0.013369044955482579
# Classification Loss:  0.7711896817870592
# BBOX Regression Loss:  0.013230269633561047
# Classification Loss:  0.7692149469703982
# BBOX Regression Loss:  0.013094297471649695
# Classification Loss:  0.7672764538182921
# BBOX Regression Loss:  0.012961066665950522
# Classification Loss:  0.7653756254462786
# BBOX Regression Loss:  0.012830458649480384
# Classification Loss:  0.7635077200694944
# BBOX Regression Loss:  0.012702380786804196
# Classification Loss:  0.7616767035218476
# BBOX Regression Loss:  0.012576694710016321
# Classification Loss:  0.7598815605596259
# BBOX Regression Loss:  0.012453471423660517
# Classification Loss:  0.758116411024853
# BBOX Regression Loss:  0.012332458531685337
# Classification Loss:  0.756385376664246
# BBOX Regression Loss:  0.012213594587314199
# Classification Loss:  0.7546869809913849
# BBOX Regression Loss:  0.012096916402000245
# Classification Loss:  0.7530200370506004
# BBOX Regression Loss:  0.0005502143529830157
# Classification Loss:  0.5875509933189109
# BBOX Regression Loss:  0.0005315584441026052
# Classification Loss:  0.5874702259346289
# BBOX Regression Loss:  0.0005200957086075235
# Classification Loss:  0.5873911763414924
# BBOX Regression Loss:  0.0005084598695652353
# Classification Loss:  0.5873355600568984
# BBOX Regression Loss:  0.000499374676771738
# Classification Loss:  0.5872353793956616
# BBOX Regression Loss:  0.0004915236213738904
# Classification Loss:  0.5871228547743808
# BBOX Regression Loss:  0.0004843099441911494
# Classification Loss:  0.5870146211492955
# BBOX Regression Loss:  0.00047795740258017616
# Classification Loss:  0.586913506631498
# BBOX Regression Loss:  0.00047329181513975185
# Classification Loss:  0.586811670452479
# BBOX Regression Loss:  0.00047284646856564057
# Classification Loss:  0.5867027208540175
# BBOX Regression Loss:  0.0004689152302339623
# Classification Loss:  0.5865976487747347
# BBOX Regression Loss:  0.0004642570966187818
# Classification Loss:  0.5864986257788576
# BBOX Regression Loss:  0.00045946042857363694
# Classification Loss:  0.5863993215425062
# BBOX Regression Loss:  0.0004548041975352341
# Classification Loss:  0.5863064642305728
# BBOX Regression Loss:  0.000450619202291156
# Classification Loss:  0.5862150865719642
# BBOX Regression Loss:  0.00044692013934427116
# Classification Loss:  0.5861163627218318
# BBOX Regression Loss:  0.0004434468096816072
# Classification Loss:  0.5860183869571728
# BBOX Regression Loss:  0.0004424560788267679
# Classification Loss:  0.5859238693253003
# BBOX Regression Loss:  0.0004397355250607573
# Classification Loss:  0.5858314439799586
# BBOX Regression Loss:  0.0004363873152545205
# Classification Loss:  0.5857419215308295
# BBOX Regression Loss:  0.0004330676012858091
# Classification Loss:  0.5856534862013721
# BBOX Regression Loss:  0.00042970553667657705
# Classification Loss:  0.5855658763988252
# BBOX Regression Loss:  0.00042651005272248134
# Classification Loss:  0.5854801076621826
# BBOX Regression Loss:  0.0004248334163868869
# Classification Loss:  0.5853961935749761
# BBOX Regression Loss:  0.00042287527880182973
# Classification Loss:  0.5853134083218045
# BBOX Regression Loss:  0.0004205798093452413
# Classification Loss:  0.5852320489041145
# BBOX Regression Loss:  0.000417957187531866
# Classification Loss:  0.5851510467843264
# BBOX Regression Loss:  0.000416245277867549
# Classification Loss:  0.5850707102074194
# BBOX Regression Loss:  0.00041369183802570416
# Classification Loss:  0.5849917076861112
# BBOX Regression Loss:  0.00041116044914096963
# Classification Loss:  0.5849145380655925
# BBOX Regression Loss:  0.0004086983786270539
# Classification Loss:  0.5848388385886645
# BBOX Regression Loss:  0.0004070790384301088
# Classification Loss:  0.5847649800556678
# BBOX Regression Loss:  0.00040531541407944516
# Classification Loss:  0.5846917841704741
# BBOX Regression Loss:  0.00040307732609411076
# Classification Loss:  0.584619368758856
# BBOX Regression Loss:  0.0004006844325355751
# Classification Loss:  0.584548803561579
# BBOX Regression Loss:  0.00039899400234176416
# Classification Loss:  0.5844791916662773
# BBOX Regression Loss:  0.00039822562980848747
# Classification Loss:  0.584410219030218
# BBOX Regression Loss:  0.00039667852230181234
# Classification Loss:  0.5843423294974582
# BBOX Regression Loss:  0.00039459365611968435
# Classification Loss:  0.5842752983767083
# BBOX Regression Loss:  0.0003926639921997709
# Classification Loss:  0.5842076076401604
# BBOX Regression Loss:  0.0003914522168637937
# Classification Loss:  0.5841384341507854
# BBOX Regression Loss:  0.0003894635348874793
# Classification Loss:  0.5840715135846819
# BBOX Regression Loss:  0.00038754239134509744
# Classification Loss:  0.584003578025036
# BBOX Regression Loss:  0.00038572411854070947
# Classification Loss:  0.5839383054662635
# BBOX Regression Loss:  0.00038438290802171685
# Classification Loss:  0.5838746186244634
# BBOX Regression Loss:  0.0003829137164943412
# Classification Loss:  0.5838100972382919
# BBOX Regression Loss:  0.00038159754071487415
# Classification Loss:  0.5837462220819473
# BBOX Regression Loss:  0.0003805365118795983
# Classification Loss:  0.5836841210906889
# BBOX Regression Loss:  0.00037896900922792116
# Classification Loss:  0.5836233696249157
# BBOX Regression Loss:  0.0003774706595749767
# Classification Loss:  0.5835626059638129
# BBOX Regression Loss:  0.0003764094912684431
# Classification Loss:  0.5835033903627528
# BBOX Regression Loss:  0.0003749434097916779
# Classification Loss:  0.5834455376676684
# BBOX Regression Loss:  0.0003736929199381736
# Classification Loss:  0.5833879961990793
# BBOX Regression Loss:  0.0003725353516612728
# Classification Loss:  0.5833309564080259
# BBOX Regression Loss:  0.00037297155037020594
# Classification Loss:  0.5832742533057628
# BBOX Regression Loss:  0.00037198305288921036
# Classification Loss:  0.583218626496653
# BBOX Regression Loss:  0.0003706822412050994
# Classification Loss:  0.5831659167675789
# BBOX Regression Loss:  0.00036928426780015954
# Classification Loss:  0.5831156593020695
# BBOX Regression Loss:  0.00036801473919842426
# Classification Loss:  0.5830645114015051
# BBOX Regression Loss:  0.00036771079738061004
# Classification Loss:  0.5830122875872954
# BBOX Regression Loss:  0.0003670418814263455
# Classification Loss:  0.5829594719822506
# BBOX Regression Loss:  0.00036598828965030264
# Classification Loss:  0.5829061242129783
# BBOX Regression Loss:  0.000364858454869713
# Classification Loss:  0.582853773914317
# BBOX Regression Loss:  0.0003639852946098135
# Classification Loss:  0.582801304978353
# BBOX Regression Loss:  0.00036319409420135354
# Classification Loss:  0.5827490321863071
# BBOX Regression Loss:  0.00036222139275690293
# Classification Loss:  0.5826979131944786
# BBOX Regression Loss:  0.0003612164007175473
# Classification Loss:  0.582648788755806
# BBOX Regression Loss:  0.000360944062853861
# Classification Loss:  0.5826007348519784
# BBOX Regression Loss:  0.0003605281064557776
# Classification Loss:  0.5825527031448536
# BBOX Regression Loss:  0.0003603045026175481
# ...
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0031780076222910664
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003137134006617617
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0030973709373361656
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0030591199033984467
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003215631042931583
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035278470334694874
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035654238944752485
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003550925775445019
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035188004649270945
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034811047455732156
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034420854762117524
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003403195951462249
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003364895814642179
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033273622766350286
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003290642948005322
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0032547450802251233
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003219664031582987
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0031853454843791605
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003152679207911726
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0031470374562065015
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003373945993607103
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034357057517553917
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034339588258869686
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034101553738460936
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003380227566647119
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00017262053831170002
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0001227248572158041
# Classification Loss:  0.0
# BBOX Regression Loss:  9.546517049548804e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  7.875579381275369e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  7.019857552626896e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  6.69837055115581e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0002340820643535899
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0029116249945892137
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003437433414110423
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00333689647077807
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0031074764756352548
# Classification Loss:  0.0
# BBOX Regression Loss:  0.002872898719862051
# Classification Loss:  0.0
# BBOX Regression Loss:  0.002661274342503839
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0024754146268134245
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0023128217550132564
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00217451285972385
# Classification Loss:  0.0
# BBOX Regression Loss:  0.002837555402152297
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004087766654978203
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004224644674983994
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004107183612887403
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003947026499631655
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003780027467115415
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003620415006467289
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003471603345014169
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033339355326240396
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0032065856424551673
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0030885854853184274
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0029790484660123994
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0028771248581033622
# Classification Loss:  0.0
# BBOX Regression Loss:  0.002782081994493952
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0026932698288465668
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0026132610783692885
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003308070990144339
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037772495597654197
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003816223437608363
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037606431487308134
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036757480047162603
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035856923630624934
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003496272875185559
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003410091719582582
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033276848239302994
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00324904445496267
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00317398854338325
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0031023566930420366
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0030339180922266014
# Classification Loss:  0.0
# BBOX Regression Loss:  0.002968526631617137
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0029063979645848267
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00312318362375214
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0038980982290916654
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003999475917597819
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0039775483913434915
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003921911646762897
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0038558971172522115
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037876024462754716
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003720059018105469
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003654274447801371
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003590581956949016
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035290460697048743
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034695825470286695
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003412117325118024
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033567356502584396
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003314605214663786
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003669807173439419
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037769696811496777
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037684861479752945
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037273470983312934
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036777975389739315
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036259585844302367
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003574448347375871
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003523894346084461
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034746185218321184
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034266850553750475
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00338017173544792
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033482362550513885
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037068695322765664
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003807859525035592
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0038021698171016864
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003767948231843021
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037259461400351254
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036814947686016914
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036369119059903635
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003592998575980337
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035500066691701204
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035080035628615
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003466999245128312
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003426959627197351
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0033879565108021724
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034439435095508838
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037064997114304495
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003734264736044137
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037173131383089544
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036853139116701556
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003648831710253784
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0036112673358067574
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035737656205611177
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003536854305926726
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0035006382168904864
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0034651494662367856
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003430388635647226
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003396642248346729
# Classification Loss:  0.0
# BBOX Regression Loss:  0.019321678273586763
# Classification Loss:  0.0
# BBOX Regression Loss:  0.024517141792198847
# Classification Loss:  0.0
# BBOX Regression Loss:  0.018696908339467133
# Classification Loss:  0.0
# BBOX Regression Loss:  0.014622859673626306
# Classification Loss:  0.0
# BBOX Regression Loss:  0.011868499670246684
# Classification Loss:  0.0
# BBOX Regression Loss:  0.009943740532078122
# Classification Loss:  0.0
# BBOX Regression Loss:  0.008540893488910994
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0074799928449835905
# Classification Loss:  0.0
# BBOX Regression Loss:  0.006652185407087758
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00598922968617882
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005446627267314158
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004994483095939403
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004611950617700158
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004284158373613738
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004000208965318715
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0037519887474681364
# Classification Loss:  0.0
# BBOX Regression Loss:  0.003746963945085037
# Classification Loss:  0.0
# BBOX Regression Loss:  0.008822925832041601
# Classification Loss:  0.0
# BBOX Regression Loss:  0.009550050739187575
# Classification Loss:  0.0
# BBOX Regression Loss:  0.009468889851974652
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00914940187161192
# Classification Loss:  0.0
# BBOX Regression Loss:  0.008781671303436897
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00841967126116683
# Classification Loss:  0.0
# BBOX Regression Loss:  0.008076961601092293
# Classification Loss:  0.0
# BBOX Regression Loss:  0.007757900431864309
# Classification Loss:  0.0
# BBOX Regression Loss:  0.007461838795399848
# Classification Loss:  0.0
# BBOX Regression Loss:  0.007187087277363442
# Classification Loss:  0.0
# BBOX Regression Loss:  0.006931728531286815
# Classification Loss:  0.0
# BBOX Regression Loss:  0.006693869711320352
# Classification Loss:  0.0
# BBOX Regression Loss:  0.006471800606684863
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00626400512404069
# Classification Loss:  0.0
# BBOX Regression Loss:  0.006069155493531543
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005886099876861552
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005713804611709976
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0055513514467717085
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005397914760223151
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0052527773979090114
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005115297990214564
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004984878227334684
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004861003719938539
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004743199743381588
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004631040936436116
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004524173380930977
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004428854238152541
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005281412481548793
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005611329163940572
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005627438642335593
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00555800209271026
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005459316648037447
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005356273024808615
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005253684513543759
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005153708529567075
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0050570386301567955
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0049638301500921555
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004873974711484486
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00478732935405489
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004703729436294097
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004623018859797615
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0045450633972901056
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0044697379459157005
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004396914988132754
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004326469326564144
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004258309736183194
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004208940557408723
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005124336058357493
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00532281322019435
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00534523094958827
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005297814396838759
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005233586915665952
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005163510064231035
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005092663044953086
# Classification Loss:  0.0
# BBOX Regression Loss:  0.005022812249140628
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004954519138609085
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004887904808946859
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004823028875405635
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004759859851009252
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004698336970186718
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004638393541247096
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004579978157885471
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004523041024981972
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004467521361905207
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00441336911692231
# Classification Loss:  0.0
# BBOX Regression Loss:  0.0043605376680739836
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004308985163872639
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004258658566602459
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004210113228442513
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004641133075780816
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004880962733094862
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004914692035542713
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004890972729125577
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004848063721845178
# Classification Loss:  0.0
# BBOX Regression Loss:  0.00479918368561992
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004749146397080909
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004699336907522162
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004650225874302514
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004602043440976514
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004554826355858505
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004508559102448495
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004463231951780332
# Classification Loss:  0.0
# BBOX Regression Loss:  0.004418822370840374
# Classification Loss:  0.0
# BBOX Regression Loss:  2.4105436642895693e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  2.5163958909817865e-05
# Classification Loss:  0.0

# %% [markdown]
# ## 想要Train VOC,COCO可以參考原Github:https://github.com/amdegroot/ssd.pytorch
